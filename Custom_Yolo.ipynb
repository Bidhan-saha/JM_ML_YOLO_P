# %% [markdown]
# <a href="https://colab.research.google.com/github/Bidhan-saha/JM_ML_YOLO_P/blob/main/Custom_Yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Sep  6 05:03:30 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Build a new model from your custom YAML
model = YOLO('/content/JM_IMP_YOLOV12.yaml')
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ongRaXWv3HHCAVRp3H5y")
project = rf.workspace("jmsaha2025").project("pneumonia-and-normal-mbohx")
version = project.version(3)
dataset = version.download("yolov12")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# improve model

# %%
model = YOLO("/content/JM_IMP_YOLOV12.yaml")   # upload yaml data path run
model.train(data="/content/pneumonia-and-normal--3/data.yaml", epochs=10 , imgsz=640, batch=16 )
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics 8.3.194 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# mmmmm

# %%
model = YOLO("/content/JM_IMP_YOLOV12.yaml")   # upload yaml data path run
model.train(data="/content/pneumonia-and-normal--3/data.yaml", epochs=25 , imgsz=640, batch=16 )
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics 8.3.194 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# 512

# %%
model = YOLO("/content/JM_IMP_YOLOV12.yaml")   # upload yaml data path run
model.train(data="/content/pneumonia-and-normal--3/data.yaml", epochs=10 , imgsz=512, batch=16 )
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics 8.3.194 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# download folder

# %%
from google.colab import files
import shutil

# Use full path to the folder
shutil.make_archive('/content/runs/detect/train', 'zip', '/content/runs/detect/train')

# Download the zipped folder
files.download('/content/runs/detect/train')
